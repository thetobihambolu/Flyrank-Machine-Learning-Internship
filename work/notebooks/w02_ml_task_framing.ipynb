# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# We are creating a scoring model that that produces a score for each of the clients webpages based on where they rank vs where they could rank and how much it is worth if that gap closes, so that the content management team can decide which websites to prioritize for optimization.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# The target would be refresh score in which we will create by using the formula;
# refresh_score = dampened_trend_pct * (CPC * search_volume), computed only for pages with 60+ days of history.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# primary metric = precision@k (e.g., precision@20), because it directly measures whether the pages the model says to prioritize match the pages that actually deserved priority — which is exactly the decision the content team makes. Spearman and RMSE can still be useful as secondary diagnostics (e.g., Spearman to sanity-check the model isn't wildly miscalibrated across the whole list, RMSE to see if predicted magnitudes are reasonable).

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\hamto\OneDrive\Desktop\Flyrank-Machine-Learning-Internship\data\raw\content_refresh_anonymized.csv')
df.iloc[0]
# Out:
# content_id                content_304f48230142
# client_id                    client_f369cb89fc
# search_volume                             10.0
# competition                               0.67
# competition_level                         HIGH
# cpc                                       2.05
# content_type                   keyword article
# main_intent                      transactional
# word_count                              3221.0
# char_count                             20457.0
# provider_used                              NaN
# model_used                    gemini-2.5-flash
# impressions_90d                           3803
# clicks_90d                                  29
# pageviews_90d                               22
# sessions_90d                                17
# users_90d                                   16
# engaged_sessions_90d                         1
# ai_sessions_90d                              0
# scroll_events_90d                            1
# ...

# %% [markdown]
# ### One row equals an individual page

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# An if-statement encodes interactions you already anticipated and wrote down explicitly, but it can't discover interactions you didn't think to check for, e.g., old_content age, high search volume, e.t.c.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
